# %%
import pandas as pd
from vowpalwabbit import pyvw
from vowpalwabbit.DFtoVW import (
    DFtoVW,
    Feature,
    MulticlassLabel,
)
from vowpalwabbit.DFtoVWtoTBorTW import VWtoTensorboard, VWtoTensorwatchStreamer, VWtoTensorwatchClient, DFtoVWtoTBorTW 

# necessary for tensorwatch to visualize for now
# %matplotlib notebook

# %%
df = pd.read_csv('./Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# converting "Species" categorical column to integer
df['Species'] = df['Species'].map({'Iris-setosa': 1, 'Iris-versicolor': 2, 'Iris-virginica': 3})
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
target_col = "Species"

# features = [Feature(col) for col in df.columns if col != target_col]  # target column not part of Features
features = [Feature(col) for col in df.columns if col not in [target_col, 'Id']]  # 'Id' column also not part of Features along with target col
label = MulticlassLabel(label=target_col)  # target column is a multi class label column
tag = 'Id'

df_to_vw = DFtoVW(df=df, features=features, label=label, tag=tag)

# %%
vw = pyvw.vw('--oaa 3 -P 1')  # -oaa is One Agent All algo for multi class problem (seems supervised) -P 1 outputs metrics for each example

# %%
logdir = './logs'
vw_to_tb = VWtoTensorboard(logdir)

# %%
df_to_tb = DFtoVWtoTBorTW(df_to_vw.convert_df(), vw)
df_to_tb.fit(vw_to_tensorboard=vw_to_tb)  # If VWtoTensorboard instance is passed, then run the command `tensorboard --logdir logs` in the examples directory

vw_to_tb.draw_reductions_graph(vw)
vw_to_tb.show_args_as_text(vw)

# %%
logfile = './iris.log'
vw_to_tw = VWtoTensorwatchStreamer(logfile, 4001)
# Out:
# Previous blocking call on IOLoop is not yet complete!
# [Debug][0]: FileStream started : /home/muhammadammarabid/vowpal_wabbit/python/examples/iris-df-to-vw-to-tensorboard/iris.log : t=1312.98

# %%
df_to_tb = DFtoVWtoTBorTW(df_to_vw.convert_df(), vw)
df_to_tb.fit(vw_to_tensorwatch=vw_to_tw)

# %%
# As in jupyter when one cell is running other cell cannot run, so running client first
vw_to_tw_client = VWtoTensorwatchClient(logfile, 4001)
vw_to_tw_client.plot_metrics()
# Out:
# Exception ignored in: <function VWtoTensorwatchClient.__del__ at 0x7f3016d41790>
# Traceback (most recent call last):
#   File "/home/muhammadammarabid/.local/lib/python3.8/site-packages/vowpalwabbit-8.11.0-py3.8-linux-x86_64.egg/vowpalwabbit/DFtoVWtoTBorTW.py", line 228, in __del__
# [Debug][0]: FileStream started : /home/muhammadammarabid/vowpal_wabbit/python/examples/iris-df-to-vw-to-tensorboard/iris.log : t=1317.37
# [Debug][0]: FileStream started : /home/muhammadammarabid/vowpal_wabbit/python/examples/iris-df-to-vw-to-tensorboard/iris.log : t=1317.37
# [Debug][0]: FileStream started : /home/muhammadammarabid/vowpal_wabbit/python/examples/iris-df-to-vw-to-tensorboard/iris.log : t=1317.37
# [Debug][0]: FileStream started : /home/muhammadammarabid/vowpal_wabbit/python/examples/iris-df-to-vw-to-tensorboard/iris.log : t=1317.38
# ERROR:asyncio:Exception in callback BaseAsyncIOLoop._handle_events(145, 1)
# handle: <Handle BaseAsyncIOLoop._handle_events(145, 1)>
# Traceback (most recent call last):
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 139, in _handle_events
#     handler_func(fileobj, events)
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/zmq/eventloop/zmqstream.py", line 452, in _handle_events
#     zmq_events = self.socket.EVENTS
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/zmq/sugar/attrsettr.py", line 48, in __getattr__
#     return self._get_attr_opt(upper_key, opt)
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/zmq/sugar/attrsettr.py", line 52, in _get_attr_opt
#     return self.get(opt)
#   File "zmq/backend/cython/socket.pyx", line 472, in zmq.backend.cython.socket.Socket.get
#   File "zmq/backend/cython/socket.pyx", line 135, in zmq.backend.cython.socket._check_closed
# zmq.error.ZMQError: Socket operation on non-socket
#     self.client.close()
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/tensorwatch/watcher_client.py", line 48, in close
#     super(WatcherClient, self).close()
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/tensorwatch/watcher_base.py", line 50, in close
#     self._stream_factory.close()
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/tensorwatch/stream_factory.py", line 28, in close
#     stream.close()
#   File "/home/muhammadammarabid/anaconda3/lib/python3.8/site-packages/tensorwatch/file_stream.py", line 23, in close
#     utils.debug_log('FileStream is closed', os.path.realpath(self._file.name), verbosity=0)
# AttributeError: 'NoneType' object has no attribute 'name'
# Exception ignored in: <function VWtoTensorwatchStreamer.__del__ at 0x7f3016d415e0>
# Traceback (most recent call last):
#   File "/home/muhammadammarabid/.local/lib/python3.8/site-packages/vowpalwabbit-8.11.0-py3.8-linux-x86_64.egg/vowpalwabbit/DFtoVWtoTBorTW.py", line 159, in __del__
#     self.watcher.close()
# AttributeError: 'VWtoTensorwatchStreamer' object has no attribute 'watcher'
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),))
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),))
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),))
# <img src="data:image/png;base64,..." width="800">
# HBox(children=(Output(),))
