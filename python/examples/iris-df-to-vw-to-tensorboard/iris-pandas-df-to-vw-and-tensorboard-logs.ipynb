# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from vowpalwabbit import pyvw
from vowpalwabbit.DFtoVW import (
    DFtoVW,
    Feature,
    MulticlassLabel,
)
import tensorboardX as tx
from datetime import datetime
from vowpalwabbit.DFtoVWtoTensorboard import DFtoVWtoTensorboard

# %%
df = pd.read_csv('./Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# converting "Species" categorical column to integer
def categorical_to_int(specie):
    if specie == 'Iris-setosa':
        return 1
    elif specie == 'Iris-versicolor':
        return 2
    elif specie == 'Iris-virginica':
        return 3
    
df['Species'] = df['Species'].apply(categorical_to_int)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
# Splitting train test
train, test = train_test_split(df, test_size=0.1)

# %%
print("Length of test:", len(train))
test
# Out:
# Length of test: 135
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 78    79            6.0           2.9            4.5           1.5        2
# 5      6            5.4           3.9            1.7           0.4        1
# 46    47            5.1           3.8            1.6           0.2        1
# 36    37            5.5           3.5            1.3           0.2        1
# 24    25            4.8           3.4            1.9           0.2        1
# 128  129            6.4           2.8            5.6           2.1        3
# 15    16            5.7           4.4            1.5           0.4        1
# 68    69            6.2           2.2            4.5           1.5        2
# 70    71            5.9           3.2            4.8           1.8        2
# 4      5            5.0           3.6            1.4           0.2        1
# 63    64            6.1           2.9            4.7           1.4        2
# 61    62            5.9           3.0            4.2           1.5        2
# 77    78            6.7           3.0            5.0           1.7        2
# 136  137            6.3           3.4            5.6           2.4        3
# 19    20            5.1           3.8            1.5           0.3        1

# %%
print("Length of test:", len(test))
test
# Out:
# Length of test: 15
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 78    79            6.0           2.9            4.5           1.5        2
# 5      6            5.4           3.9            1.7           0.4        1
# 46    47            5.1           3.8            1.6           0.2        1
# 36    37            5.5           3.5            1.3           0.2        1
# 24    25            4.8           3.4            1.9           0.2        1
# 128  129            6.4           2.8            5.6           2.1        3
# 15    16            5.7           4.4            1.5           0.4        1
# 68    69            6.2           2.2            4.5           1.5        2
# 70    71            5.9           3.2            4.8           1.8        2
# 4      5            5.0           3.6            1.4           0.2        1
# 63    64            6.1           2.9            4.7           1.4        2
# 61    62            5.9           3.0            4.2           1.5        2
# 77    78            6.7           3.0            5.0           1.7        2
# 136  137            6.3           3.4            5.6           2.4        3
# 19    20            5.1           3.8            1.5           0.3        1

# %%
target_col = "Species"

# features = [Feature(col) for col in df.columns if col != target_col]  # target column not part of Features
features = [Feature(col) for col in df.columns if col != target_col and col != 'Id']  # 'Id' column also not part of Features along with target col
label = MulticlassLabel(label=target_col)  # target column is a multi class label column
tag = 'Id'

df_to_vw = DFtoVW(df=df, features=features, label=label, tag=tag)

# %%
vw = pyvw.vw('--oaa 3 -P 1')  # -oaa is One Agent All algo for multi class problem (seems supervised) -P 1 outputs metrics for each example

# %%
# Before running this run command `rm -rf ./logs` in this directory to remove any previous logs for tensorboard
df_to_tb = DFtoVWtoTensorboard(df_to_vw, vw)
df_to_tb.fit(train)  # by default metrics are logged to tensorboard, now run in the current directory command `tensorboard --logdir ./logs`
# Out:
# average_loss:0.000000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.500000	since_last:1.000000	label: 3	prediction: 1	num_features: 5
# average_loss:0.666667	since_last:1.000000	label: 1	prediction: 3	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.600000	since_last:1.000000	label: 3	prediction: 1	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.571429	since_last:1.000000	label: 3	prediction: 1	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.555556	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.600000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.636364	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.666667	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.615385	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.642857	since_last:1.000000	label: 1	prediction: 2	num_features: 5
# average_loss:0.600000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.625000	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.647059	since_last:1.000000	label: 1	prediction: 2	num_features: 5
# average_loss:0.611111	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.578947	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.600000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.619048	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.590909	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.565217	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.541667	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.520000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.481481	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.500000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.482759	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.500000	since_last:1.000000	label: 1	prediction: 3	num_features: 5
# average_loss:0.516129	since_last:1.000000	label: 1	prediction: 3	num_features: 5
# average_loss:0.531250	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.545455	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.529412	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.514286	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.486486	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.473684	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.487179	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.475000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.487805	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.476190	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.488372	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.477273	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.466667	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.456522	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.446809	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.437500	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.448980	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.460000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.450980	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.461538	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.471698	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.462963	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.472727	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.464286	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.456140	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.465517	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.457627	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.450000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.442623	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.435484	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.444444	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.437500	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.446154	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.454545	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.447761	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.441176	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.434783	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.428571	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.436620	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.430556	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.438356	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.445946	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.440000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.434211	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.428571	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.435897	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.430380	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.425000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.419753	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.426829	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.421687	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.416667	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.411765	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.406977	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.402299	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.397727	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.393258	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.388889	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.395604	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.391304	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.387097	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.382979	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.378947	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.385417	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.381443	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.377551	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.373737	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.370000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.366337	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.362745	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.368932	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.375000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.380952	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.377358	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.383178	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.379630	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.376147	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.372727	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.369369	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.366071	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.362832	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.359649	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.365217	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.362069	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.358974	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.364407	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.361345	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.366667	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.363636	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.368852	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.365854	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.362903	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.360000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.365079	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.370079	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.367188	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.372093	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.369231	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.366412	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.363636	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.368421	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.373134	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.370370	since_last:0.000000	label: 2	prediction: 2	num_features: 5
