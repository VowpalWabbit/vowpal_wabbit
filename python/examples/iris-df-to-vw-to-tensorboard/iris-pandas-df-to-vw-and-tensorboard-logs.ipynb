# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from vowpalwabbit import pyvw
from vowpalwabbit.DFtoVW import (
    DFtoVW,
    Feature,
    MulticlassLabel,
)
import tensorboardX as tx
from datetime import datetime
from vowpalwabbit.DFtoVWtoTensorboard import DFtoVWtoTensorboard

# %%
df = pd.read_csv('./Iris.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# converting "Species" categorical column to integer
def categorical_to_int(specie):
    if specie == 'Iris-setosa':
        return 1
    elif specie == 'Iris-versicolor':
        return 2
    elif specie == 'Iris-virginica':
        return 3
    
df['Species'] = df['Species'].apply(categorical_to_int)
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
# Splitting train test
train, test = train_test_split(df, test_size=0.1)

# %%
print("Length of test:", len(train))
test
# Out:
# Length of test: 135
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 64    65            5.6           2.9            3.6           1.3        2
# 147  148            6.5           3.0            5.2           2.0        3
# 54    55            6.5           2.8            4.6           1.5        2
# 81    82            5.5           2.4            3.7           1.0        2
# 63    64            6.1           2.9            4.7           1.4        2
# 90    91            5.5           2.6            4.4           1.2        2
# 145  146            6.7           3.0            5.2           2.3        3
# 97    98            6.2           2.9            4.3           1.3        2
# 92    93            5.8           2.6            4.0           1.2        2
# 109  110            7.2           3.6            6.1           2.5        3
# 118  119            7.7           2.6            6.9           2.3        3
# 116  117            6.5           3.0            5.5           1.8        3
# 15    16            5.7           4.4            1.5           0.4        1
# 139  140            6.9           3.1            5.4           2.1        3
# 93    94            5.0           2.3            3.3           1.0        2

# %%
print("Length of test:", len(test))
test
# Out:
# Length of test: 15
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 64    65            5.6           2.9            3.6           1.3        2
# 147  148            6.5           3.0            5.2           2.0        3
# 54    55            6.5           2.8            4.6           1.5        2
# 81    82            5.5           2.4            3.7           1.0        2
# 63    64            6.1           2.9            4.7           1.4        2
# 90    91            5.5           2.6            4.4           1.2        2
# 145  146            6.7           3.0            5.2           2.3        3
# 97    98            6.2           2.9            4.3           1.3        2
# 92    93            5.8           2.6            4.0           1.2        2
# 109  110            7.2           3.6            6.1           2.5        3
# 118  119            7.7           2.6            6.9           2.3        3
# 116  117            6.5           3.0            5.5           1.8        3
# 15    16            5.7           4.4            1.5           0.4        1
# 139  140            6.9           3.1            5.4           2.1        3
# 93    94            5.0           2.3            3.3           1.0        2

# %%
target_col = "Species"

# features = [Feature(col) for col in df.columns if col != target_col]  # target column not part of Features
features = [Feature(col) for col in df.columns if col != target_col and col != 'Id']  # 'Id' column also not part of Features along with target col
label = MulticlassLabel(label=target_col)  # target column is a multi class label column
tag = 'Id'

df_to_vw = DFtoVW(df=df, features=features, label=label, tag=tag)

# %%
vw = pyvw.vw('--oaa 3 -P 1')  # -oaa is One Agent All algo for multi class problem (seems supervised) -P 1 outputs metrics for each example

# %%
# Before running this run command `rm -rf ./logs` in this directory to remove any previous logs for tensorboard
df_to_tb = DFtoVWtoTensorboard(df_to_vw, vw)
df_to_tb.fit(train)  # by default metrics are logged to tensorboard, now run in the current directory command `tensorboard --logdir ./logs`
# Out:
# average_loss:1.000000	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.666667	since_last:1.000000	label: 1	prediction: 2	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.400000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.500000	since_last:1.000000	label: 1	prediction: 2	num_features: 5
# average_loss:0.571429	since_last:1.000000	label: 1	prediction: 2	num_features: 5
# average_loss:0.500000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.444444	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.400000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.363636	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.416667	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.461538	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.500000	since_last:1.000000	label: 3	prediction: 1	num_features: 5
# average_loss:0.466667	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.437500	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.411765	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.388889	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.368421	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.400000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.380952	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.409091	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.391304	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.375000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.360000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.346154	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.333333	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.321429	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.310345	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.322581	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.312500	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.303030	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.323529	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.314286	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.305556	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.324324	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.315789	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.307692	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.325000	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.317073	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.309524	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.325581	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.318182	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.311111	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.304348	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.297872	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.312500	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.306122	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.300000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.294118	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.307692	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.301887	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.296296	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.290909	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.285714	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.280702	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.275862	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.288136	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.300000	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.311475	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.322581	since_last:1.000000	label: 2	prediction: 1	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.328125	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.323077	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.318182	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.313433	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.323529	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.328571	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.323944	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.328767	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.324324	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.328947	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.324675	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.329114	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.325000	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.329268	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.325301	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.333333	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.329412	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.325581	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.321839	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.318182	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.325843	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.322222	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.318681	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.315217	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.311828	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.308511	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.305263	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.302083	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.309278	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.306122	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.303030	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.300000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.297030	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.294118	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.291262	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.288462	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.285714	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.292453	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.289720	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.296296	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.302752	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.300000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.297297	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.303571	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.300885	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.298246	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.295652	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.301724	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.299145	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.296610	since_last:0.000000	label: 3	prediction: 3	num_features: 5
# average_loss:0.302521	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.300000	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.305785	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.311475	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.317073	since_last:1.000000	label: 2	prediction: 3	num_features: 5
# average_loss:0.314516	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.312000	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.317460	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.314961	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.320312	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.317829	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.323077	since_last:1.000000	label: 3	prediction: 2	num_features: 5
# average_loss:0.320611	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.318182	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.315789	since_last:0.000000	label: 1	prediction: 1	num_features: 5
# average_loss:0.313433	since_last:0.000000	label: 2	prediction: 2	num_features: 5
# average_loss:0.318519	since_last:1.000000	label: 3	prediction: 2	num_features: 5
